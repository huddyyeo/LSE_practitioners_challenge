# %%
from google.colab import files
src = list(files.upload().values())[0]
open('corrfx.py','wb').write(src)
import corrfx
# Out:
#      <input type="file" id="files-477556e2-dc6b-46fd-88c7-2953e902305f" name="files[]" multiple disabled />
#      <output id="result-477556e2-dc6b-46fd-88c7-2953e902305f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corrfx.py to corrfx.py

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
main='https://raw.githubusercontent.com/huddyyeo/LSE_practitioners_challenge/master/Data/'
yieldd='UK_gilt_yield_data.csv'
yield_format='%Y-%m-%d'
ftse='FTSE100_closing_data.csv'
ftse_format='%d/%m/%Y'
inflation='UK_inflation_data.csv'
inflation_format='%Y'
gdp='UK_GDP_data.csv'
gdp_format='%Y'
risk_free_rate='UK_risk_free_rate_data.csv'
risk_free_rate_format=''

url_list=[ftse,yieldd,inflation,gdp,risk_free_rate]
data_type=[1,1,1,1,1]
date_format=[ftse_format,yield_format,inflation_format,gdp_format,risk_free_rate_format]
names=['FTSE','Yield','Inflation','GDP','RF Rate']

#creation of our data environment
data_env=corrfx.data_environment(main,url_list,data_type,date_format)

# %%
x=data_env.resample_all(interpolate_method='linear')
x=x.dropna()
x=x.iloc[:-10]

# %%
x.head()
# Out:
#             Log-return_x  Log-return_y  Log-return_x  Log-return_y  Log-return
# Date
# 1998-04-30     -0.006620     -0.014805     -0.152081      0.033737    0.055940
# 1998-05-31      0.000536      0.009104     -0.176808      0.033744   -0.015525
# 1998-06-30     -0.102557     -0.043981     -0.200738      0.033751   -0.090821
# 1998-07-31     -0.038144     -0.077264     -0.225466      0.033759   -0.098759
# 1998-08-31      0.067794     -0.029115     -0.250194      0.033766   -0.007070

# %%
plt.plot(x.iloc[:,4])

# %%
#run 12 month rolling correlations
corr=corrfx.roll_corr(x.iloc[:,2].values,x.iloc[:,3].values,12)
plt.figure(figsize=[10,8])
plt.plot(corr,label="Corr")
plt.legend()
plt.show()

# %%
#importing arma models
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
#fn that returns p,q parameters for an ARMA model that would give lowest AIC
def find_lowest_aic(corr):
  '''
  Searches for lowest AIC value for ARMA model of different parameters.
  Returns p,q,lowest_AIC_value
  '''
  p=-1
  q=-1
  lowest_aic=np.inf
  for i in range(0,5):
    for j in range(0,5):
      arma=sm.tsa.ARIMA(corr,order=(i,0,j))
      try:
        arma_fit=arma.fit()
        if arma_fit.aic<lowest_aic:
          p=i
          q=j
          lowest_aic=arma_fit.aic
      except:
        print(i,j,'error')
  return p,q,lowest_aic

# %%
#identify parameters for each univariate factor, based on test set that excludes last 12 months in the data
length=len(data_env.data)
orders=[]
for n in range(length):
  p,q,_=find_lowest_aic(x.iloc[:-12,n].values)
  orders.append((p,q))

# %%
orders
# Out:
# [(0, 0), (3, 1), (4, 4), (4, 4), (3, 3)]

# %%
data_env

# %%
arma=sm.tsa.ARIMA(x.iloc[:-12,0].values,order=(0,0,0))
arma_fit=arma.fit()
arma_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  238
# Model:                     ARMA(0, 0)   Log Likelihood                 438.019
# Method:                           css   S.D. of innovations              0.038
# Date:                Thu, 05 Mar 2020   AIC                           -872.039
# Time:                        16:28:09   BIC                           -865.094
# Sample:                             0   HQIC                          -869.240
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.002      0.312      0.755      -0.004       0.006
# ==============================================================================
# """

# %%
#find parameters for all correlations, based on a test set that excludes the last 12 months in the data
length=len(data_env.data)
orders=np.ndarray((length,length),dtype=object)
for i in range(length):
  for j in range(length):
    orders[i,j]=0
    if i==j:
      continue
    if orders[j,i]!=0:
      continue
    corr=corrfx.roll_corr(x.iloc[:,i].values,x.iloc[:,j].values,12)
    corr=corr[:-12]
    p,q,_=find_lowest_aic(corr)
    orders[i,j]=(p,q)
    print(i,j,'complete')

# %%
#triangular matrix of the best ARMA orders for each factor's correlations
orders
# Out:
# array([[0, 0, 0, 0, 0],
#        [(4, 3), 0, 0, 0, 0],
#        [(1, 0), (4, 1), 0, 0, 0],
#        [(1, 0), (4, 2), (2, 0), 0, 0],
#        [(2, 1), (4, 0), (4, 1), (4, 2), 0]], dtype=object)

# %%
np.array([[0, 0, 0, 0, 0],
       [(3, 1), 0, 0, 0, 0],
       [(1, 0), (4, 1), 0, 0, 0],
       [(1, 0), (4, 2), (2, 0), 0, 0],
       [(2, 1), (4, 0), (4, 1), (4, 2), 0]])
# Out:
# array([[0, 0, 0, 0, 0],
#        [(3, 1), 0, 0, 0, 0],
#        [(1, 0), (4, 1), 0, 0, 0],
#        [(1, 0), (4, 2), (2, 0), 0, 0],
#        [(2, 1), (4, 0), (4, 1), (4, 2), 0]], dtype=object)

# %%
#for each correlation, plot the actual, forecasted and CI 
plt.figure(figsize=[20,20])

for i in range(length):
  for j in range(length):

    if orders[i,j]==0:
      continue
    plt.subplot(5,5,5*i+j+1)
    corr=corrfx.roll_corr(x.iloc[:,i].values,x.iloc[:,j].values,12)
    arma=sm.tsa.ARIMA(corr[:-12],order=(orders[i,j][0],0,orders[i,j][1]))
    arma_fit=arma.fit()
    forecasts=arma_fit.forecast(steps=12)
    plt.plot(corr[-12:],label='actual')
    plt.plot(forecasts[0],label='forecasted')
    plt.plot(forecasts[2][:,0],label='CI',color='red')
    plt.plot(forecasts[2][:,1],color='red')
    name=names[i]+','+names[j]
    plt.title(name)

plt.legend()
plt.savefig('correlations.png',dpi=300)
files.download('correlations.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
